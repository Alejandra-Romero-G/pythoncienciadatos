# %%
num1 = 4
num1
# Out:
# 4

# %% [markdown]
# Importaos la librería de pandas

# %%
import pandas as pd

# %% [markdown]
# Creamos datos para el Dataframe

# %%
datos = {
    'Nombres' : ['Ana','Adian','Lucia','Antonia'],
    'Edad' : [23,25,12,40],
    'Ciudades':['Madrid', 'Sevilla','Toledo','Gijon']
}

# %% [markdown]
# Creamos un Dataframe con los datos

# %%
df = pd.DataFrame(datos)
df
# Out:
#    Nombres  Edad Ciudades
# 0      Ana    23   Madrid
# 1    Adian    25  Sevilla
# 2    Lucia    12   Toledo
# 3  Antonia    40    Gijon

# %% [markdown]
# Voy a filtrar Datos por edad

# %%
df[df['Edad'] > 24]
# Out:
#    Nombres  Edad Ciudades
# 1    Adian    25  Sevilla
# 3  Antonia    40    Gijon
